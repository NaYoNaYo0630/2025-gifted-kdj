# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


x_value = np.array([9.711307073,
0.7956544127,
1.866425874,
6.070416584,
0.04306186361,
7.127298511,
8.474656913,
2.712239848,
4.982193571,
6.008536341,
7.157298671,
8.680544956,
6.631189149,
5.879336292,
6.616682719,
1.146765466,
3.427339736,
2.568570141,
6.337365982,
4.237250255])

y_value = np.array([22.42261415,
4.591308825,
6.732851747,
15.14083317,
3.086123727,
17.25459702,
19.94931383,
8.424479695,
12.96438714,
15.01707268,
17.31459734,
20.36108991,
16.2623783,
14.75867258,
16.23336544,
5.293530932,
9.854679472,
8.137140282,
15.67473196,
11.47450051])

threshold = 15
y_categorical = np.where(y_value > threshold, 1, 0)

x_value.reshape(-1, 2)
y_value.reshape(-1, 2)

train_input = [[x_value[i], y_value[i]] for i in range(len(x_value))]
plt.scatter(x_value, y_value, marker='*')
plt.show()

ln = LinearRegreesion()

ln.fit(train_input, y_categorical)

print(lg.coef_)
print(lg.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-91b585492899> in <cell line: 0>()
#      59 plt.show()
#      60
# ---> 61 ln = LinearRegreesion()
#      62
#      63 ln.fit(train_input, y_categorical)
#
# NameError: name 'LinearRegreesion' is not defined

# %%
from sklearn.linear_model import LogisticRegression # Import LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


x_value = np.array([9.711307073,
0.7956544127,
1.866425874,
6.070416584,
0.04306186361,
7.127298511,
8.474656913,
2.712239848,
4.982193571,
6.008536341,
7.157298671,
8.680544956,
6.631189149,
5.879336292,
6.616682719,
1.146765466,
3.427339736,
2.568570141,
6.337365982,
4.237250255])

y_value = np.array([22.42261415,
4.591308825,
6.732851747,
15.14083317,
3.086123727,
17.25459702,
19.94931383,
8.424479695,
12.96438714,
15.01707268,
17.31459734,
20.36108991,
16.2623783,
14.75867258,
16.23336544,
5.293530932,
9.854679472,
8.137140282,
15.67473196,
11.47450051])

threshold = 15
y_categorical = np.where(y_value > threshold, 1, 0)

#x_value.reshape(-1, 2) # These lines don't have any effect
#y_value.reshape(-1, 2) # because the results aren't assigned to a variable

train_input = [[x_value[i], y_value[i]] for i in range(len(x_value))]
plt.scatter(x_value, y_value, marker='*')
plt.show()

lg = LogisticRegression() # Changed to LogisticRegression and assigned to lg

lg.fit(train_input, y_categorical)

print(lg.coef_) # Changed ln to lg
print(lg.intercept_) # Changed ln to lg
# Out:
# [[0.5121241  1.02229873]]
# [-17.45875321]
